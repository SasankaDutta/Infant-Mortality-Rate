# %%
#Infant mortality rate is an MDG indicator. Infant mortality rate is the probability of a child born in a specific year or period dying before reaching the age of one,
# if subject to age-specific mortality rates of that period.Causes of infant mortality The leading causes of infant mortality vary by country and region, but some of the most
# common causes include: Preterm birth and low birth weight Birth defects Sudden infant death syndrome (SIDS) Infections Maternal pregnancy complications Risk factors for infant 
# mortality There are a number of factors that can increase a baby's risk of death, including: Being born prematurely or with a low birth weight Having a birth defect Being born 
# to a mother who is young, unmarried, or smokes Living in poverty Living in a community with limited access to healthcare Reducing infant mortality There are a number of things 
# that can be done to reduce infant mortality, including: Providing adequate prenatal care to all pregnant women Preventing preterm birth and low birth weight Treating birth defects 
# Educating parents about safe sleep practices Vaccinating infants against preventable diseases Improving access to healthcare for all families

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#importing the csv file for the analysis

df=pd.read_csv('D:\Internship\Cranes Varsity\Project\Infant Mortality Rate\Infant_Mortality.csv', index_col=0)
df
# Out:
#                           2004 2005 2006 2007 2008 2009 2010 2011 2012 2013  \
# State/Union Territory
# Andaman & Nicobar Islands   19   27   31   34   31   27   25   23   24   24
# Andhra Pradesh              59   57   56   54   52   49   46   43   41   39
# Arunachal Pradesh           38   37   40   37   32   32   31   32   33   32
# Assam                       66   68   67   66   64   61   58   55   55   54
# Bihar                       61   61   60   58   56   52   48   44   43   42
# Chandigarh                  21   19   23   27   28   25   22   20   20   21
# Chhattisgarh                60   63   61   59   57   54   51   48   47   46
# Dadra & Nagar Haveli        48   42   35   34   34   37   38   35   33   31
# Daman & Diu                 37   28   28   27   31   24   23   22   22   20
# Delhi                       32   35   37   36   35   33   30   28   25   24
# Goa                         17   16   15   13   10   11   10   11   10    9
# ...

# %%
df.head()
# Out:
#                           2004 2005 2006 2007 2008 2009 2010 2011 2012 2013  \
# State/Union Territory
# Andaman & Nicobar Islands   19   27   31   34   31   27   25   23   24   24
# Andhra Pradesh              59   57   56   54   52   49   46   43   41   39
# Arunachal Pradesh           38   37   40   37   32   32   31   32   33   32
# Assam                       66   68   67   66   64   61   58   55   55   54
# Bihar                       61   61   60   58   56   52   48   44   43   42
#
#                            2014  2015  2016  2017  2018 2019 2020
# State/Union Territory
# Andaman & Nicobar Islands    22    20    16    14     9    7    7
# Andhra Pradesh               39    37    34    32    29   25   24
# Arunachal Pradesh            30    30    36    42    37   29   21
# Assam                        49    47    44    44    41   40   36
# Bihar                        42    42    38    35    32   29   27

# %%
df.shape
# Out:
# (37, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, Andaman & Nicobar Islands to ALL INDIA
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2004    37 non-null     object
#  1   2005    37 non-null     object
#  2   2006    37 non-null     object
#  3   2007    37 non-null     object
#  4   2008    37 non-null     object
#  5   2009    37 non-null     object
#  6   2010    37 non-null     object
#  7   2011    37 non-null     object
#  8   2012    37 non-null     object
#  9   2013    37 non-null     object
#  10  2014    37 non-null     int64
#  11  2015    37 non-null     int64
#  12  2016    37 non-null     int64
#  13  2017    37 non-null     int64
#  14  2018    37 non-null     int64
#  15  2019    37 non-null     object
#  16  2020    37 non-null     object
# dtypes: int64(5), object(12)
# memory usage: 5.2+ KB

# %%
df['2004'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of State/Union Territory
# Andaman & Nicobar Islands    19
# Andhra Pradesh               59
# Arunachal Pradesh            38
# Assam                        66
# Bihar                        61
# Chandigarh                   21
# Chhattisgarh                 60
# Dadra & Nagar Haveli         48
# Daman & Diu                  37
# Delhi                        32
# Goa                          17
# Gujarat                      53
# Haryana                      61
# Himachal Pradesh             51
# Jammu & Kashmir              49
# Jharkhand                    49
# Karnataka                    49
# Kerala                       12
# Lakshadweep                  30
# Madhya Pradesh               79
# Maharashtra                  36
# Manipur                      14
# Meghalaya                    54
# Mizoram                      19
# Nagaland                     17
# Odisha                       77
# Puducherry                   24
# ...

# %%
df.columns
# Out:
# Index(['2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
df=df.loc[:,'2004':'2020']
df
# Out:
#                           2004 2005 2006 2007 2008 2009 2010 2011 2012 2013  \
# State/Union Territory
# Andaman & Nicobar Islands   19   27   31   34   31   27   25   23   24   24
# Andhra Pradesh              59   57   56   54   52   49   46   43   41   39
# Arunachal Pradesh           38   37   40   37   32   32   31   32   33   32
# Assam                       66   68   67   66   64   61   58   55   55   54
# Bihar                       61   61   60   58   56   52   48   44   43   42
# Chandigarh                  21   19   23   27   28   25   22   20   20   21
# Chhattisgarh                60   63   61   59   57   54   51   48   47   46
# Dadra & Nagar Haveli        48   42   35   34   34   37   38   35   33   31
# Daman & Diu                 37   28   28   27   31   24   23   22   22   20
# Delhi                       32   35   37   36   35   33   30   28   25   24
# Goa                         17   16   15   13   10   11   10   11   10    9
# ...

# %%
asm=df.loc['Assam',: :2]
asm
# Out:
# 2004    66
# 2006    67
# 2008    64
# 2010    58
# 2012    55
# 2014    49
# 2016    44
# 2018    41
# 2020    36
# Name: Assam, dtype: object

# %%
asm = asm.astype(int)
asm.dtype
# Out:
# dtype('int32')

# %%
asm.size
# Out:
# 9

# %%
bih=df.loc['Bihar',: :2]
bih
# Out:
# 2004    61
# 2006    60
# 2008    56
# 2010    48
# 2012    43
# 2014    42
# 2016    38
# 2018    32
# 2020    27
# Name: Bihar, dtype: object

# %%
bih = bih.astype(int)
bih.dtype
# Out:
# dtype('int32')

# %%
bih.size
# Out:
# 9

# %%
import seaborn as sns

plt.xlabel('Year')
plt.ylabel('Infant Mortality')
sns.scatterplot(x = list(asm.index) , y = list(asm.values),label='Assam')
sns.scatterplot(x = list(bih.index) , y = list(bih.values),label='Bihar')
# Out:
# C:\Users\Sasanka Dutta\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Sasanka Dutta\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Sasanka Dutta\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.lineplot(x = list(asm.index) , y = list(asm.values),label='Assam')
sns.lineplot(x = list(bih.index) , y = list(bih.values),label='Bihar')
# Out:
# C:\Users\Sasanka Dutta\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Sasanka Dutta\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Sasanka Dutta\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
plt.hist(df)
# Out:
# (array([[10., 13.,  8.,  6.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [ 4.,  5.,  3.,  6., 11.,  8.,  0.,  0.,  0.,  0.],
#         [ 4.,  5.,  3.,  4.,  5.,  4., 10.,  2.,  0.,  0.],
#         [ 5.,  4.,  3.,  5.,  1.,  2.,  4., 13.,  0.,  0.],
#         [ 0.,  5.,  4.,  4.,  5.,  6.,  5.,  3.,  5.,  0.],
#         [ 5.,  5.,  6.,  4.,  5.,  3.,  6.,  2.,  1.,  0.],
#         [ 7.,  4.,  2.,  5.,  3.,  3.,  5.,  5.,  3.,  0.],
#         [ 5.,  4.,  2.,  5.,  5.,  4.,  6.,  4.,  2.,  0.],
#         [ 3.,  8.,  4.,  4.,  4.,  2.,  5.,  5.,  2.,  0.],
#         [ 2.,  7.,  7.,  4.,  4.,  5.,  0.,  3.,  5.,  0.],
#         [ 0.,  5.,  9.,  5.,  8.,  6.,  4.,  0.,  0.,  0.],
#         [ 0.,  5., 11.,  5.,  8.,  6.,  2.,  0.,  0.,  0.],
#         [ 0.,  6.,  9.,  9.,  6.,  6.,  1.,  0.,  0.,  0.],
#         [ 1.,  9.,  8.,  7.,  6.,  5.,  1.,  0.,  0.,  0.],
#         [ 5.,  8.,  7.,  7.,  5.,  4.,  1.,  0.,  0.,  0.],
#         [ 5.,  3.,  0.,  6.,  1.,  2.,  7.,  0.,  5.,  8.],
# ...

# %%
#calculate the change im life expectancy in assam from 2004 to 2020
asm_2004=df.loc['Assam','2004']
asm_2020=df.loc['Assam','2020']
print(asm_2004)
print(asm_2020)
print(int(asm_2020) - int(asm_2004))
# Out:
# 66
# 36
# -30

# %%
#calculate the change im life expectancy in bihar from 2004 to 2020
bih_2020=df.loc['Bihar','2020']
bih_2004=df.loc['Bihar','2004']
print(bih_2004)
print(bih_2020)
print(int(bih_2020) - int(bih_2004))
# Out:
# 61
# 27
# -34

# %%
df.sort_values('2020').loc[:,'2020']
# Out:
# State/Union Territory
# Delhi                         12
# Tamil Nadu                    13
# Maharashtra                   16
# Daman & Diu                  16*
# Dadra & Nagar Haveli         16*
# Jammu & Kashmir               17
# Himachal Pradesh              17
# Punjab                        18
# Tripura                       18
# Karnataka                     19
# West Bengal                   19
# Telangana                     21
# Arunachal Pradesh             21
# Gujarat                       23
# Andhra Pradesh                24
# Uttarakhand                   24
# Jharkhand                     25
# Bihar                         27
# ALL INDIA                     28
# Haryana                       28
# Meghalaya                     29
# Mizoram                        3
# Rajasthan                     32
# Odisha                        36
# Assam                         36
# Chhattisgarh                  38
# Uttar Pradesh                 38
# ...

# %%
df.sort_values('2020',).loc[:,'2020'].rank()['Assam']
# Out:
# 24.5

# %%
all_2004_2020=df.loc[:,['2004','2020']]
all_2004_2020
# Out:
#                           2004 2020
# State/Union Territory
# Andaman & Nicobar Islands   19    7
# Andhra Pradesh              59   24
# Arunachal Pradesh           38   21
# Assam                       66   36
# Bihar                       61   27
# Chandigarh                  21    8
# Chhattisgarh                60   38
# Dadra & Nagar Haveli        48  16*
# Daman & Diu                 37  16*
# Delhi                       32   12
# Goa                         17    5
# Gujarat                     53   23
# Haryana                     61   28
# Himachal Pradesh            51   17
# Jammu & Kashmir             49   17
# Jharkhand                   49   25
# Karnataka                   49   19
# Kerala                      12    6
# Lakshadweep                 30    9
# Madhya Pradesh              79   43
# Maharashtra                 36   16
# Manipur                     14    6
# Meghalaya                   54   29
# Mizoram                     19    3
# ...

# %%
#Sort the record based on the record of 2020

df_india=df.sort_values(by='2004')
df_india
# Out:
#                           2004 2005 2006 2007 2008 2009 2010 2011 2012 2013  \
# State/Union Territory
# Telangana                    .    .    .    .    .    .    .    .    .    .
# Kerala                      12   14   15   13   12   12   13   12   12   12
# Manipur                     14   13   11   12   14   16   14   11   10   10
# Nagaland                    17   18   20   21   26   26   23   21   18   18
# Goa                         17   16   15   13   10   11   10   11   10    9
# Andaman & Nicobar Islands   19   27   31   34   31   27   25   23   24   24
# Mizoram                     19   20   25   23   37   36   37   34   35   35
# Chandigarh                  21   19   23   27   28   25   22   20   20   21
# Puducherry                  24   28   28   25   25   22   22   19   17   17
# Lakshadweep                 30   22   25   24   31   25   25   24   24   24
# Sikkim                      32   30   33   34   33   34   30   26   24   22
# ...

# %%
#Sort the record based on the record of 2020

df_india.sort_values(by='2020')
# Out:
#                           2004 2005 2006 2007 2008 2009 2010 2011 2012 2013  \
# State/Union Territory
# Delhi                       32   35   37   36   35   33   30   28   25   24
# Tamil Nadu                  41   37   37   35   31   28   24   22   21   21
# Maharashtra                 36   36   35   34   33   31   28   25   25   24
# Dadra & Nagar Haveli        48   42   35   34   34   37   38   35   33   31
# Daman & Diu                 37   28   28   27   31   24   23   22   22   20
# Himachal Pradesh            51   49   50   47   44   45   40   38   36   35
# Jammu & Kashmir             49   50   52   51   49   45   43   41   39   37
# Punjab                      45   44   44   43   41   38   34   30   28   26
# Tripura                     32   31   36   39   34   31   27   29   28   26
# Karnataka                   49   50   48   47   45   41   38   35   32   31
# West Bengal                 40   38   38   37   35   33   33   32   32   31
# ...

# %%
df_7sisters=df.loc[['Assam','Nagaland','Mizoram','Manipur','Meghalaya','Arunachal Pradesh','Tripura']]
df_7sisters
# Out:
#                       2004 2005 2006 2007 2008 2009 2010 2011 2012 2013  2014  \
# State/Union Territory
# Assam                   66   68   67   66   64   61   58   55   55   54    49
# Nagaland                17   18   20   21   26   26   23   21   18   18    14
# Mizoram                 19   20   25   23   37   36   37   34   35   35    32
# Manipur                 14   13   11   12   14   16   14   11   10   10    11
# Meghalaya               54   49   53   56   58   59   55   52   49   47    46
# Arunachal Pradesh       38   37   40   37   32   32   31   32   33   32    30
# Tripura                 32   31   36   39   34   31   27   29   28   26    21
#
#                        2015  2016  2017  2018 2019 2020
# State/Union Territory
# Assam                    47    44    44    41   40   36
# Nagaland                 12    12     7     4    3    4
# Mizoram                  32    27    15     5    3    3
# Manipur                   9    11    12    11   10    6
# ...

# %%
df_7sisters=df_7sisters.loc[:,'2004':'2020':2]
df_7sisters
# Out:
#                       2004 2006 2008 2010 2012  2014  2016  2018 2020
# State/Union Territory
# Assam                   66   67   64   58   55    49    44    41   36
# Nagaland                17   20   26   23   18    14    12     4    4
# Mizoram                 19   25   37   37   35    32    27     5    3
# Manipur                 14   11   14   14   10    11    11    11    6
# Meghalaya               54   53   58   55   49    46    39    33   29
# Arunachal Pradesh       38   40   32   31   33    30    36    37   21
# Tripura                 32   36   34   27   28    21    24    27   18

# %%
df_7sisters = df_7sisters.astype(int)
df_7sisters.sort_values(by='2020')
# Out:
#                        2004  2006  2008  2010  2012  2014  2016  2018  2020
# State/Union Territory
# Mizoram                  19    25    37    37    35    32    27     5     3
# Nagaland                 17    20    26    23    18    14    12     4     4
# Manipur                  14    11    14    14    10    11    11    11     6
# Tripura                  32    36    34    27    28    21    24    27    18
# Arunachal Pradesh        38    40    32    31    33    30    36    37    21
# Meghalaya                54    53    58    55    49    46    39    33    29
# Assam                    66    67    64    58    55    49    44    41    36

# %%
df_7sisters.sort_values(by='2004')
# Out:
#                        2004  2006  2008  2010  2012  2014  2016  2018  2020
# State/Union Territory
# Manipur                  14    11    14    14    10    11    11    11     6
# Nagaland                 17    20    26    23    18    14    12     4     4
# Mizoram                  19    25    37    37    35    32    27     5     3
# Tripura                  32    36    34    27    28    21    24    27    18
# Arunachal Pradesh        38    40    32    31    33    30    36    37    21
# Meghalaya                54    53    58    55    49    46    39    33    29
# Assam                    66    67    64    58    55    49    44    41    36

# %%
df_7sisters = df_7sisters.astype(int)


plt.plot(df_7sisters.loc['Assam'],c='green',label='Assam')
plt.plot(df_7sisters.loc['Nagaland'],c='brown',label='Nagaland')
plt.plot(df_7sisters.loc['Mizoram'],c='pink',label='Mizoram')
plt.plot(df_7sisters.loc['Manipur'],c='blue',label='Manipur')
plt.plot(df_7sisters.loc['Meghalaya'],c='yellow',label='Meghalaya')
plt.plot(df_7sisters.loc['Arunachal Pradesh'],c='red',label='Arunachal Pradesh')
plt.plot(df_7sisters.loc['Tripura'],c='violet',label='Tripura')
plt.legend()
plt.plot()
# Out:
# []

# %%
plt.hist(df_7sisters)
# Out:
# (array([[0., 1., 2., 0., 1., 1., 0., 1., 0., 1.],
#         [0., 1., 1., 1., 0., 2., 0., 1., 0., 1.],
#         [0., 1., 0., 1., 2., 1., 0., 0., 1., 1.],
#         [0., 1., 0., 2., 1., 1., 0., 0., 2., 0.],
#         [0., 1., 1., 1., 1., 1., 0., 1., 1., 0.],
#         [0., 2., 1., 0., 2., 0., 1., 1., 0., 0.],
#         [0., 2., 0., 2., 0., 2., 1., 0., 0., 0.],
#         [2., 1., 0., 1., 1., 2., 0., 0., 0., 0.],
#         [3., 0., 2., 0., 1., 1., 0., 0., 0., 0.]]),
#  array([ 3. ,  9.4, 15.8, 22.2, 28.6, 35. , 41.4, 47.8, 54.2, 60.6, 67. ]),
#  <a list of 9 BarContainer objects>)

# %%
df_7sisters=df_7sisters.transpose() #to convert rows to columns
df_7sisters
# Out:
# State/Union Territory  Assam  Nagaland  Mizoram  Manipur  Meghalaya  \
# 2004                      66        17       19       14         54
# 2006                      67        20       25       11         53
# 2008                      64        26       37       14         58
# 2010                      58        23       37       14         55
# 2012                      55        18       35       10         49
# 2014                      49        14       32       11         46
# 2016                      44        12       27       11         39
# 2018                      41         4        5       11         33
# 2020                      36         4        3        6         29
#
# State/Union Territory  Arunachal Pradesh  Tripura
# 2004                                  38       32
# 2006                                  40       36
# 2008                                  32       34
# 2010                                  31       27
# ...

# %%
df_7sisters = df_7sisters.astype(int)
df_7sisters.plot()
# Out:
# <Axes: >

# %%
df_7sisters.plot(kind='bar',y=['Assam','Nagaland'])
# Out:
# <Axes: >

# %%
df_7sisters=df_7sisters.transpose() #to convert rows to columns
df_7sisters
# Out:
#                        2004  2006  2008  2010  2012  2014  2016  2018  2020
# State/Union Territory
# Assam                    66    67    64    58    55    49    44    41    36
# Nagaland                 17    20    26    23    18    14    12     4     4
# Mizoram                  19    25    37    37    35    32    27     5     3
# Manipur                  14    11    14    14    10    11    11    11     6
# Meghalaya                54    53    58    55    49    46    39    33    29
# Arunachal Pradesh        38    40    32    31    33    30    36    37    21
# Tripura                  32    36    34    27    28    21    24    27    18

# %%
#finding the difference of the 7sister states  

df_7sisters=df_7sisters.loc[:,['2004','2020']]
df_7sisters['Diff']=df_7sisters.loc[:,'2004'] - df_7sisters.loc[:,'2020']
df_7sisters
# Out:
#                        2004  2020  Diff
# State/Union Territory
# Assam                    66    36    30
# Nagaland                 17     4    13
# Mizoram                  19     3    16
# Manipur                  14     6     8
# Meghalaya                54    29    25
# Arunachal Pradesh        38    21    17
# Tripura                  32    18    14
